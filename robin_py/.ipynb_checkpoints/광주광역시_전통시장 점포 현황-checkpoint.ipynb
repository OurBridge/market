# %%
# 광주광역시_전통시장 점포 현황

import os
import sys
import urllib.request
import json

url = "https://api.odcloud.kr/api/15095853/v1/uddi:bc80387d-e19f-4659-b53b-cd0245ef61a0?page=186&perPage=10&serviceKey=CDKWiYrOyT0XapzcNW1DIE3exiXZz7XIpAIrrsOC/rkFLM1niU7Ukkn0Hg8Cfe/lepOAe/jJeHlTHSroOSOgYg=="
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"currentCount":10,"data":[{"경도":"126.9051252","데이터기준일자":"2021-09-10","배달서비스":"N","분류":"도소매","비고":null,"소재지도로명주소":"광주광역시 서구 독립로 180","소재지지번주소":"광주광역시 서구 양동 43-8","시군구":"서구","시장명":"양동산업용품시장","위도":"35.14947631","전화번호":"062-365-0689","점포(ID)":1851,"점포명":"금호상사","주력상품":"보일러판매","취급품목":"보일러","홈페이지":null},{"경도":"126.9051453","데이터기준일자":"2021-09-10","배달서비스":"N","분류":"도소매","비고":null,"소재지도로명주소":"광주광역시 서구 독립로 180","소재지지번주소":"광주광역시 서구 양동 43-8","시군구":"서구","시장명":"양동산업용품시장","위도":"35.14946808","전화번호":"062-368-2544","점포(ID)":1852,"점포명":"형제공업사","주력상품":"리어카.평상제작","취급품목":"공업사","홈페이지":null},{"경도":"126.9051580","데이터기준일자":"2021-09-10","배달서비스":"N","분류":"도소매","비고":null,"소재지도로명주소":"광주광역시 서구 독립로 180","소재지지번주소":"광주광역시 서구 양동 43-8","시군구":"서구","시장명":"양동산업용품시장","위도":"35.14947356","전화번호":"062-369-3700","점포(ID)":1853,"점포명":"조광밸브수도","주력상품":"밸프.수도","취급품목":"건설자재","홈페이지":null},{"경도":"126.9052910","데이터기준일자":"2021-09-10","배달서비스":"N","분류":"세탁소","비고":null,"소재지도로명주소":"광주광역시 서구 구성로93번길 5","소재지지번주소":"광주광역시 서구 양동 182-42","시군구":"서구
# ...

# %%
# 전체 개수

response_dict = json.loads(response_body)
total_count = response_dict['totalCount']
print(total_count)
# Out:
# 2711
